# %%
import pandas as pd
import joblib

# %%
df = pd.read_csv(r'../data/Processed_Train_Data.csv')
df.head(10)
# Out:
#    month  day  order  country  session_id  page1_main_category  \
# 0      6   22     21       29       15648                    3
# 1      5   19      6       29       10018                    2
# 2      7   15      2       29       19388                    3
# 3      5    2      2       29        7181                    2
# 4      6    9     16       29       13493                    2
# 5      8    8      1       29       23239                    3
# 6      5    2     11       29        7109                    3
# 7      4   16      3        9        3980                    3
# 8      6    5      3       29       12984                    2
# 9      5    1      1       29        6958                    1
#
#    page2_clothing_model  colour  location  model_photography  price  price_2  \
# 0                    88      13         1                  2     48        1
# 1                    60      13         3                  1     57        1
# ...

# %%
df_train = pd.read_csv('..\data\Train_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132379 entries, 0 to 132378
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   month                 132379 non-null  int64
#  1   day                   132379 non-null  int64
#  2   order                 132379 non-null  int64
#  3   country               132379 non-null  int64
#  4   session_id            132379 non-null  int64
#  5   page1_main_category   132379 non-null  int64
#  6   page2_clothing_model  132379 non-null  int64
#  7   colour                132379 non-null  int64
#  8   location              132379 non-null  int64
#  9   model_photography     132379 non-null  int64
#  10  price                 132379 non-null  int64
#  11  price_2               132379 non-null  int64
#  12  page                  132379 non-null  int64
#  13  Purchase Completed    132379 non-null  int64
# ...

# %%
model1 = joblib.load('../models/best_Random_Forest_classifier.pkl')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
scaler = joblib.load("../models/Classification_scaler.pkl")

# %%
df_1 = df[['order', 'country', 'session_id', 'page1_main_category', 'colour', 
            'location', 'model_photography', 'price', 'price_2', 'page', 'page2_clothing_model', 
            'Purchase Completed']]

# %%
df10 = df_train[df_train["session_id" ]== 15648]
df10
# Out:
#         year  month  day  order  country  session_id  page1_main_category  \
# 0       2008      6   22     21       29       15648                    3
# 2459    2008      6   22     29       29       15648                    3
# 4164    2008      6   22    103       29       15648                    3
# 4862    2008      6   22     94       29       15648                    2
# 5450    2008      6   22     11       29       15648                    1
# ...      ...    ...  ...    ...      ...         ...                  ...
# 126345  2008      6   22     83       29       15648                    1
# 126964  2008      6   22     17       29       15648                    1
# 127316  2008      6   22     91       29       15648                    1
# 128983  2008      6   22     26       29       15648                    3
# 132253  2008      6   22    101       29       15648                    3
#
#        page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
target_col = "Purchase Completed"

# %%
X_train = df_1.drop(columns=[target_col])
y_train = df_1[target_col]

# %%
X_train.head()
X_train.shape
# Out:
# (132379, 11)

# %%
X_train.columns
# Out:
# Index(['order', 'country', 'session_id', 'page1_main_category', 'colour',
#        'location', 'model_photography', 'price', 'price_2', 'page',
#        'page2_clothing_model'],
#       dtype='object')

# %%
X_train_scaled = scaler.transform(X_train)

# %%
smote = SMOTE(sampling_strategy="auto", random_state=42)  # Use auto for automatic balancing
X_resampled, y_resampled = smote.fit_resample(X_train_scaled, y_train)

# %%
X_resampled.shape
# Out:
# (262292, 11)

# %%
y_resampled.shape
# Out:
# (262292,)

# %%
x_train,x_test,y_train,y_test = train_test_split(X_resampled,y_resampled,test_size=0.1, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=80, max_depth=8, min_samples_split=10, min_samples_leaf=4, random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=8, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=80, random_state=42)

# %%
# # Correct way to reshape test input:
# testinput = np.array([24,29,4032,4,7,2,1,43,1,5,208]).reshape(1, -1)

# # Now perform scaling
# testinput_scaled = scaler.transform(testinput)

# Perform prediction
prediction = model.predict([[24,29,4032,4,7,2,1,43,1,5,208]])
print(prediction)
# Out:
# [1]

# %%
# Perform prediction
prediction = model1.predict([[24,29,4032,4,7,2,1,43,1,5,208]])
print(prediction)
# Out:
# [1]
